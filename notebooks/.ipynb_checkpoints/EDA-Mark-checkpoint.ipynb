# %%
# getting path to base and importing dataset sucks, but copy paste this in your notebooks
import os
from pathlib import Path
import sys
py_path = Path(os.getcwd()).parent
sys.path.insert(0, str(py_path))

import dataset
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# convoluted way of getting data, I will fix bug later, but again copy paste...
data_path = f"{str(py_path)}/data/"
Dataset = dataset.Dataset()
data = Dataset.clean_data(data_path = data_path)
processed_data = Dataset.preprocess_data(cleaned_data = data)

# %% [markdown]
# # The EDA Commences...
#
# Now that the (primary source of) data is in relatively good condition, we can start to perform some basic plotting and statistical analysis to guide our intuition for modeling later on.

# %%
input_data = processed_data['input_data']
output_data = processed_data['output_data']
input_data['2020']
# Out:
#                                                Name     Farms  \
# 6                                             Farms   64672.0
# 7         Forestry, fishing, and related activities   23301.0
# 8                            Oil and gas extraction       0.0
# 9                        Mining, except oil and gas    1770.0
# 10                    Support activities for mining       0.0
# ..                                              ...       ...
# 80                        Compensation of employees   29197.0
# 81  Taxes on production and imports, less subsidies  -34717.0
# 82                          Gross operating surplus  140634.0
# 83                                Total Value Added  135114.0
# 84                            Total Industry Output  402599.0
#
#     Forestry, fishing, and related activities  Oil and gas extraction  \
# 6                                       357.0                     0.0
# 7                                      6172.0                     0.0
# 8                                         0.0                 21515.0
# 9                                         0.0                    62.0
# 10                                        0.0                  7031.0
# ..                                        ...                     ...
# 80                                    31226.0                  4612.0
# 81                                     -207.0                 34326.0
# 82                                     9976.0                 31791.0
# 83                                    40995.0                 70729.0
# 84                                    55584.0                220680.0
#
#     Mining, except oil and gas  Support activities for mining  Utilities  \
# 6                         35.0                           16.0        0.0
# 7                         60.0                            0.0        0.0
# 8                          2.0                            0.0    16908.0
# 9                       5495.0                           46.0     6866.0
# 10                      1731.0                         1058.0        0.0
# ..                         ...                            ...        ...
# 80                      9746.0                        42521.0    91206.0
# 81                      4037.0                        -1050.0    65603.0
# 82                     22803.0                        10829.0   178770.0
# 83                     36585.0                        52299.0   335580.0
# 84                     79777.0                        88958.0   525166.0
#
#     Construction  Wood products  Nonmetallic mineral products  ...  \
# 6         2267.0            0.0                           0.0  ...
# 7            0.0        11367.0                           1.0  ...
# 8            0.0            0.0                           0.0  ...
# 9        19595.0            2.0                        6889.0  ...
# 10           0.0            0.0                           0.0  ...
# ..           ...            ...                           ...  ...
# 80      648869.0        25479.0                       30983.0  ...
# 81      -60053.0        -1508.0                        -675.0  ...
# 82      387883.0        16886.0                       34084.0  ...
# 83      976699.0        40857.0                       64392.0  ...
# 84     1868903.0       111701.0                      130033.0  ...
#
#     Federal national nondefense: Consumption expenditures  \
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# ..                                                ...
# 80                                                0.0
# 81                                                0.0
# 82                                                0.0
# 83                                                NaN
# 84                                           460969.0
#
#     Federal national nondefense: Gross investment in structures  \
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# ..                                                ...
# 80                                                0.0
# 81                                                0.0
# 82                                                0.0
# 83                                                NaN
# 84                                            17584.0
#
#     Federal national nondefense: Gross investment in equipment  \
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# ..                                                ...
# 80                                                0.0
# 81                                                0.0
# 82                                                0.0
# 83                                                NaN
# 84                                            20559.0
#
#     Federal national nondefense: Gross investment in intellectual property products  \
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# ..                                                ...
# 80                                                0.0
# 81                                                0.0
# 82                                                0.0
# 83                                                NaN
# 84                                           121337.0
#
#     State and local: Consumption expenditures  \
# 6                                         0.0
# 7                                         0.0
# 8                                         0.0
# 9                                         0.0
# 10                                        0.0
# ..                                        ...
# 80                                        0.0
# 81                                        0.0
# 82                                        0.0
# 83                                        NaN
# 84                                  1916544.0
#
#     State and local: Gross investment in structures  \
# 6                                               0.0
# 7                                               0.0
# 8                                               0.0
# 9                                               0.0
# 10                                              0.0
# ..                                              ...
# 80                                              0.0
# 81                                              0.0
# 82                                              0.0
# 83                                              NaN
# 84                                         345478.0
#
#     State and local: Gross investment in equipment  \
# 6                                              0.0
# 7                                              0.0
# 8                                              0.0
# 9                                              0.0
# 10                                             0.0
# ..                                             ...
# 80                                             0.0
# 81                                             0.0
# 82                                             0.0
# 83                                             NaN
# 84                                         50365.0
#
#     State and local: Gross investment in intellectual property products  \
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# ..                                                ...
# 80                                                0.0
# 81                                                0.0
# 82                                                0.0
# 83                                                NaN
# 84                                            45372.0
#
#     Total Final Uses (GDP)  Total Commodity Output
# 6                  97117.0                396051.0
# 7                  -1998.0                 62646.0
# 8                 -29101.0                204583.0
# 9                   9502.0                 77904.0
# 10                 78733.0                 88612.0
# ..                     ...                     ...
# 80                     0.0                     0.0
# 81                     0.0                     0.0
# 82                     0.0                     0.0
# 83              20893744.0                     NaN
# 84                     NaN              36478052.0
#
# [79 rows x 95 columns]
